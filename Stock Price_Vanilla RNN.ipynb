# %%
pip install numpy pandas scikit-learn matplotlib tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\deepe\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\deepe\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: scikit-learn in c:\users\deepe\anaconda3\lib\site-packages (1.5.1)
# Requirement already satisfied: matplotlib in c:\users\deepe\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: tensorflow in c:\users\deepe\anaconda3\lib\site-packages (2.19.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\deepe\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\deepe\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\deepe\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\deepe\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\deepe\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\deepe\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\deepe\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\deepe\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\deepe\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\deepe\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\deepe\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\deepe\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\deepe\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (2.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (3.9.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in c:\users\deepe\anaconda3\lib\site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\deepe\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\deepe\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\deepe\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\deepe\anaconda3\lib\site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\deepe\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\deepe\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\deepe\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\deepe\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\deepe\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\deepe\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\deepe\anaconda3\lib\site-packages (from tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\deepe\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\deepe\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\deepe\anaconda3\lib\site-packages (from rich->keras>=3.5.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\deepe\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense
from sklearn.metrics import mean_squared_error, mean_absolute_error
import numpy as np

# Load your data
df = pd.read_excel("C:/Users/deepe/sp500_historical_data.xlsx", sheet_name="in")
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date')

# Step 1: Extract 'Close' prices and scale
close_prices = df[['Close']].values
scaler = MinMaxScaler()
scaled_close = scaler.fit_transform(close_prices)

# Step 2: Create sequences
def create_sequences(data, window_size=30):
    X, y = [], []
    for i in range(window_size, len(data)):
        X.append(data[i-window_size:i, 0])
        y.append(data[i, 0])
    return np.array(X), np.array(y)

window_size = 30
X, y = create_sequences(scaled_close, window_size)
X = X.reshape((X.shape[0], X.shape[1], 1))

# Step 3: Split into train and test
split = int(len(X) * 0.8)
X_train, X_test = X[:split], X[split:]
y_train, y_test = y[:split], y[split:]

# Step 4: Build RNN model
model = Sequential()
model.add(SimpleRNN(50, activation='tanh', input_shape=(window_size, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), verbose=1)

# Step 5: Predict
y_pred_scaled = model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred_scaled)
y_test_orig = scaler.inverse_transform(y_test.reshape(-1, 1))

# Calculate metrics
rmse = np.sqrt(mean_squared_error(y_test_orig, y_pred))
mae = mean_absolute_error(y_test_orig, y_pred)

print(f"RMSE: {rmse:.4f}")
print(f"MAE: {mae:.4f}")

# Step 6: Plot
plt.figure(figsize=(12,6))
plt.plot(y_test_orig, label='Actual')
plt.plot(y_pred, label='Predicted')
plt.title('Stock Price Prediction with RNN')
plt.xlabel('Time Step')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\deepe\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 0.0016 - val_loss: 0.0091
# Epoch 2/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.2222e-05 - val_loss: 0.0035
# Epoch 3/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.0733e-05 - val_loss: 0.0037
# Epoch 4/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 1.0772e-05 - val_loss: 0.0026
# Epoch 5/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.4883e-06 - val_loss: 0.0025
# Epoch 6/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.6413e-06 - val_loss: 0.0020
# Epoch 7/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 7.2940e-06 - val_loss: 0.0018
# Epoch 8/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 6.6093e-06 - val_loss: 0.0021
# Epoch 9/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 6.6875e-06 - val_loss: 0.0014
# Epoch 10/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 7.6108e-06 - val_loss: 0.0014
# Epoch 11/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - loss: 6.1233e-06 - val_loss: 0.0011
# Epoch 12/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 5.9739e-06 - val_loss: 0.0011
# Epoch 13/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 6.7566e-06 - val_loss: 9.5128e-04
# Epoch 14/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 6.2241e-06 - val_loss: 7.2730e-04
# Epoch 15/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 5.2885e-06 - val_loss: 4.9594e-04
# Epoch 16/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 5.7287e-06 - val_loss: 6.2894e-04
# Epoch 17/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 5.5812e-06 - val_loss: 5.3647e-04
# Epoch 18/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 5.2485e-06 - val_loss: 5.0169e-04
# Epoch 19/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 8.3560e-06 - val_loss: 2.4267e-04
# Epoch 20/20
# 269/269 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 4.7638e-06 - val_loss: 4.0389e-04
# 68/68 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step
# RMSE: 120.3383
# MAE: 89.3654
